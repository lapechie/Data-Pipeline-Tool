# %% [markdown]
# # Data-Pipeline-Tools
#
# Schedule, run and monitor python workflows

# %% [markdown]
# Start with a DataFrame of of processes.
#
# Each process requires:
# * Process name, ID or equivalent
# * What the process depends on. Comma separated for multiple dependencies.
# * Filepath Location of the process script
# * The status of the process
# * When the process was last run

# %%
import pandas as pd

# sample DataFrame spec
schedule_df = pd.read_csv("sample_spec.csv")
schedule_df
# Out:
#         process                   dep_on                location     status  \
# 0     extract_2                      NaN    scripts/extract_2.py  no status
# 1     extract_3                      NaN    scripts/extract_3.py  no status
# 2   transform_1      extract_1,extract_2  scripts/transform_1.py  no status
# 3   transform_2                extract_1  scripts/transform_2.py  no status
# 4   transform_3  transform_1,transform_4  scripts/transform_3.py  no status
# 5   transform_4                extract_3  scripts/transform_4.py  no status
# 6   transform_5              transform_4  scripts/transform_5.py  no status
# 7   transform_6              transform_2  scripts/transform_6.py  no status
# 8     extract_1                      NaN    scripts/extract_1.py  no status
# 9        load_1              transform_2       scripts/load_1.py  no status
# 10       load_2  transform_5,transform_6       scripts/load_2.py  no status
# 11       load_3              transform_3       scripts/load_3.py  no status
# 12       load_4              transform_4       scripts/load_4.py  no status
#
#    last_run
# 0     never
# 1     never
# 2     never
# 3     never
# 4     never
# 5     never
# 6     never
# 7     never
# 8     never
# 9     never
# 10    never
# 11    never
# 12    never

# %%
from Pipeline import Pipeline

# Create a Pipeline instance using the DataFrame
pipeline = Pipeline(schedule_df,
                    process = "process",
                    dep_on = "dep_on", 
                    location = "location", 
                    status = "status", 
                    last_run="last_run")

# visualise the pipeline
pipeline.draw()

# %%
# Schedule is stored in the object
pipeline.schedule
# Out:
#         process                   dep_on                location     status  \
# 0     extract_2                      NaN    scripts/extract_2.py  no status
# 1     extract_3                      NaN    scripts/extract_3.py  no status
# 2   transform_1      extract_1,extract_2  scripts/transform_1.py  no status
# 3   transform_2                extract_1  scripts/transform_2.py  no status
# 4   transform_3  transform_1,transform_4  scripts/transform_3.py  no status
# 5   transform_4                extract_3  scripts/transform_4.py  no status
# 6   transform_5              transform_4  scripts/transform_5.py  no status
# 7   transform_6              transform_2  scripts/transform_6.py  no status
# 8     extract_1                      NaN    scripts/extract_1.py  no status
# 9        load_1              transform_2       scripts/load_1.py  no status
# 10       load_2  transform_5,transform_6       scripts/load_2.py  no status
# 11       load_3              transform_3       scripts/load_3.py  no status
# 12       load_4              transform_4       scripts/load_4.py  no status
#
#    last_run
# 0     never
# 1     never
# 2     never
# 3     never
# 4     never
# 5     never
# 6     never
# 7     never
# 8     never
# 9     never
# 10    never
# 11    never
# 12    never

# %%
# run the schedule
# the pipeline sorts the process order based on the depenecies automatically
pipeline.execute()
# Out:
# running  extract_1
# running  extract_2
# running  extract_3

# %%
# we can see the schedule was sorted, the status and last_run were updated as the schedule was executed
pipeline.schedule
# Out:
#         process                   dep_on                location  \
# 0     extract_1                      NaN    scripts/extract_1.py
# 1     extract_2                      NaN    scripts/extract_2.py
# 2     extract_3                      NaN    scripts/extract_3.py
# 3   transform_2                extract_1  scripts/transform_2.py
# 4   transform_1      extract_1,extract_2  scripts/transform_1.py
# 5   transform_4                extract_3  scripts/transform_4.py
# 6   transform_6              transform_2  scripts/transform_6.py
# 7        load_1              transform_2       scripts/load_1.py
# 8   transform_3  transform_1,transform_4  scripts/transform_3.py
# 9   transform_5              transform_4  scripts/transform_5.py
# 10       load_4              transform_4       scripts/load_4.py
# 11       load_3              transform_3       scripts/load_3.py
# 12       load_2  transform_5,transform_6       scripts/load_2.py
#
#                status    last_run
# 0               error       never
# 1             success  2022-02-19
# 2               error       never
# 3   dependency failed       never
# 4   dependency failed       never
# 5   dependency failed       never
# 6   dependency failed       never
# 7   dependency failed       never
# 8   dependency failed       never
# 9   dependency failed       never
# 10  dependency failed       never
# 11  dependency failed       never
# 12  dependency failed       never

# %%
# visualise the pipeline
pipeline.draw()

# %%
# errors are captures and stored in a list
pipeline.stderr_list
# Out:
# [b'Traceback (most recent call last):\r\n  File "D:\\repo\\Data-Pipeline-Tools\\scripts\\extract_1.py", line 4, in <module>\r\n    z = x + y + u\r\nNameError: name \'u\' is not defined\r\n',
#  b'',
#  b"python: can't open file 'D:\\\\repo\\\\Data-Pipeline-Tools\\\\scripts\\\\extract_3.py': [Errno 2] No such file or directory\r\n"]

# %%
### Future Enhancements
# group trees and parralel run
# show errors visually
# interactive visual
# networkx.algorithms.dag.is_directed_acyclic_graph
# networkx.algorithms.dag.ancestors
# networkx.algorithms.dag.descendants
